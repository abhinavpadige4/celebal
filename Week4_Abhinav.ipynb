# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavpadige4/celebal/blob/main/Week4_Abhinav.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 CIFAR-10 Image Classification Learning Project
# ## Build and Compare **ANN vs CNN** on CIFAR-10
#
# This notebook is designed for **students and beginners** to learn:
# - How image classification works
# - Why **CNN performs better than ANN**
# - How architecture impacts performance
# - How training strategies improve results
#
# 🎯 **Learning Goal:** Understand the complete DL pipeline by **reading the markdown + running the ready code**.

# %% [markdown]
# # 🧠 Problem Statement
# Build an image classification model on the **CIFAR-10 dataset** using:
#
# 1. **Artificial Neural Network (ANN)**
# 2. **Convolutional Neural Network (CNN)**
#
# Then compare:
# - Accuracy
# - Loss curves
# - Generalization
# - Training strategies (dropout, batch norm, augmentation)
#
# ---
# ### 📦 CIFAR-10 Classes
# Airplane, Automobile, Bird, Cat, Deer, Dog, Frog, Horse, Ship, Truck

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

print("TensorFlow version:", tf.__version__)

# %% [markdown]
# # 📥 Load Dataset
# We use **CIFAR-10**, which contains **60,000 color images of size 32×32×3**.
# - 50,000 training images
# - 10,000 test images

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

print("Train shape:", x_train.shape)
print("Test shape:", x_test.shape)

# %% [markdown]
# ## 🖼️ Visualize Sample Images

# %%
plt.figure(figsize=(10,5))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(x_train[i])
    plt.title(class_names[y_train[i][0]])
    plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 🧹 Preprocessing
# We normalize pixel values from **0–255 → 0–1** so training becomes stable.

# %%
x_train_norm = x_train / 255.0
x_test_norm = x_test / 255.0

x_train_flat = x_train_norm.reshape(len(x_train_norm), -1)
x_test_flat = x_test_norm.reshape(len(x_test_norm), -1)

# %% [markdown]
# # 🔹 Part 1: ANN Model
# ANN treats images as **flat vectors**, so it cannot preserve spatial features.
# This helps students understand **why CNN is better for images**.

# %%
ann_model = models.Sequential([
    layers.Dense(512, activation='relu', input_shape=(3072,)),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.Dense(10, activation='softmax')
])

ann_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

ann_history = ann_model.fit(
    x_train_flat, y_train,
    epochs=10,
    validation_split=0.1,
    batch_size=64
)

# %%
ann_test_loss, ann_test_acc = ann_model.evaluate(x_test_flat, y_test)
print("ANN Test Accuracy:", ann_test_acc)

# %% [markdown]
# # 🔹 Part 2: CNN Model
# CNN preserves **spatial relationships** using:
# - Convolution layers
# - Pooling
# - Feature extraction
# - Hierarchical learning
#
# This is why CNN performs much better for image tasks.

# %%
cnn_model = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(128, (3,3), activation='relu'),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(10, activation='softmax')
])

cnn_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

cnn_history = cnn_model.fit(
    x_train_norm, y_train,
    epochs=10,
    validation_split=0.1,
    batch_size=64
)

# %%
cnn_test_loss, cnn_test_acc = cnn_model.evaluate(x_test_norm, y_test)
print("CNN Test Accuracy:", cnn_test_acc)

# %% [markdown]
# ## 📈 Compare Learning Curves

# %%
plt.figure(figsize=(10,4))
plt.plot(ann_history.history['val_accuracy'], label='ANN Val Acc')
plt.plot(cnn_history.history['val_accuracy'], label='CNN Val Acc')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("ANN vs CNN Validation Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# # 🚀 Training Strategy Upgrade: Data Augmentation
# This strategy improves generalization by generating transformed images.

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
])

aug_cnn_model = models.Sequential([
    data_augmentation,
    layers.Conv2D(32, 3, activation='relu', input_shape=(32,32,3)),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(10, activation='softmax')
])

aug_cnn_model.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])

# Suggested optional run:
# aug_history = aug_cnn_model.fit(x_train_norm, y_train, epochs=10, validation_split=0.1)

# %% [markdown]
# # 📊 Final Comparison Table

# %%
comparison = pd.DataFrame({
    "Model": ["ANN", "CNN"],
    "Test Accuracy": [ann_test_acc, cnn_test_acc]
})
comparison

# %% [markdown]
# # 🎓 Student Learning Tasks
# Try these tasks after understanding the notebook:
#
# ### ✅ Beginner Tasks
# 1. Increase ANN layers and observe performance
# 2. Change CNN filters from 32→64→128
# 3. Increase epochs to 20
# 4. Add **EarlyStopping**
# 5. Add **data augmentation training**

# %% [markdown]
# # ✅ Conclusion
# - **ANN works**, but ignores image structure
# - **CNN extracts spatial features**, so it performs significantly better
# - **Training strategies** like dropout, batch norm, and augmentation improve results
# - This project builds strong fundamentals for **computer vision interviews and deep learning projects**

# %% [markdown]
# ## 🎓 Taskss

# %% [markdown]
# ### ✅ Task 1: Increase ANN layers and observe performance
# I will create a new ANN model (`ann_model_v2`) with an additional dense layer to observe its impact on performance.

# %%
ann_model_v2 = models.Sequential([
    layers.Dense(512, activation='relu', input_shape=(3072,)),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'), # Added new layer
    layers.Dropout(0.2), # Added new dropout for new layer
    layers.Dense(10, activation='softmax')
])

ann_model_v2.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Training ANN Model V2...")
ann_history_v2 = ann_model_v2.fit(
    x_train_flat, y_train,
    epochs=10,
    validation_split=0.1,
    batch_size=64
)

ann_test_loss_v2, ann_test_acc_v2 = ann_model_v2.evaluate(x_test_flat, y_test)
print("ANN V2 Test Accuracy:", ann_test_acc_v2)

# %%
plt.figure(figsize=(10,4))
plt.plot(ann_history.history['val_accuracy'], label='ANN V1 Val Acc')
plt.plot(ann_history_v2.history['val_accuracy'], label='ANN V2 Val Acc (More Layers)')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("ANN Models Validation Accuracy Comparison")
plt.legend()
plt.show()

# %% [markdown]
# ### ✅ Task 2: Change CNN filters from 32→64→128
# Upon reviewing the existing `cnn_model` definition (in cell `WewTlxGiOlAe`), the CNN already uses filters with 32, 64, and 128 channels. So, this task is already addressed by the current model architecture.

# %% [markdown]
# ### ✅ Task 3 & 4: Increase epochs to 20 and add EarlyStopping
# I will now retrain both the original ANN and CNN models with 20 epochs and incorporate EarlyStopping to prevent overfitting.

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Define EarlyStopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=3,          # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True # Restore model weights from the epoch with the best value of the monitored quantity
)

print("Retraining ANN Model with 20 epochs and EarlyStopping...")
ann_history_20_epochs = ann_model.fit(
    x_train_flat, y_train,
    epochs=20, # Increased epochs
    validation_split=0.1,
    batch_size=64,
    callbacks=[early_stopping]
)

print("Retraining CNN Model with 20 epochs and EarlyStopping...")
cnn_history_20_epochs = cnn_model.fit(
    x_train_norm, y_train,
    epochs=20, # Increased epochs
    validation_split=0.1,
    batch_size=64,
    callbacks=[early_stopping]
)

# %%
ann_test_loss_es, ann_test_acc_es = ann_model.evaluate(x_test_flat, y_test)
print("ANN Test Accuracy (20 epochs + ES):", ann_test_acc_es)

cnn_test_loss_es, cnn_test_acc_es = cnn_model.evaluate(x_test_norm, y_test)
print("CNN Test Accuracy (20 epochs + ES):", cnn_test_acc_es)

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(ann_history_20_epochs.history['val_accuracy'], label='ANN Val Acc (20 epochs + ES)')
plt.plot(ann_history.history['val_accuracy'], label='ANN Val Acc (10 epochs)')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("ANN Validation Accuracy (20 epochs vs 10 epochs)")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(cnn_history_20_epochs.history['val_accuracy'], label='CNN Val Acc (20 epochs + ES)')
plt.plot(cnn_history.history['val_accuracy'], label='CNN Val Acc (10 epochs)')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("CNN Validation Accuracy (20 epochs vs 10 epochs)")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### ✅ Task 5: Add data augmentation training
# I will now train the `aug_cnn_model` which includes data augmentation, using 20 epochs and EarlyStopping.

# %%
print("Training CNN Model with Data Augmentation...")
aug_history = aug_cnn_model.fit(
    x_train_norm, y_train,
    epochs=20, # Increased epochs
    validation_split=0.1,
    batch_size=64,
    callbacks=[early_stopping]
)

aug_cnn_test_loss, aug_cnn_test_acc = aug_cnn_model.evaluate(x_test_norm, y_test)
print("Augmented CNN Test Accuracy:", aug_cnn_test_acc)

# %% [markdown]
# ### 📊 Updated Final Comparison Table

# %%
comparison_updated = pd.DataFrame({
    "Model": [
        "ANN (10 epochs)",
        "ANN (More Layers, 10 epochs)",
        "ANN (20 epochs + ES)",
        "CNN (10 epochs)",
        "CNN (20 epochs + ES)",
        "CNN (Augmented, 20 epochs + ES)"
    ],
    "Test Accuracy": [
        ann_test_acc,
        ann_test_acc_v2,
        ann_test_acc_es,
        cnn_test_acc,
        cnn_test_acc_es,
        aug_cnn_test_acc
    ]
})
display(comparison_updated)

# %%
plt.figure(figsize=(10, 4))
plt.plot(cnn_history_20_epochs.history['val_accuracy'], label='CNN Val Acc (20 epochs + ES)')
plt.plot(aug_history.history['val_accuracy'], label='CNN Val Acc (Augmented, 20 epochs + ES)')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("CNN Validation Accuracy: With vs Without Data Augmentation")
plt.legend()
plt.show()
